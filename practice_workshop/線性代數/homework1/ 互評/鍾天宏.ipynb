# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import sympy as s

# %%
X= np.linspace(0,3.14,100)
C= np.linspace(-3.14,0,100)

U= np.linspace(-1,1,100)
Y= np.sin(X)
Z= np.cos(X)

I= np.sqrt(1-U**2)
plt.plot(X+1,Y+5)
plt.plot(C-1,Y+5)

plt.plot(U,I+2.5)
plt.plot(U,-I+2.5)
