# %%
import numpy as np 
import matplotlib.pyplot as plt
def f(x):
    return np.exp(x)-1
x = np.linspace(0,10,1000)
y = f(x)
plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt
def f(x):
    return np.exp(x)-1
x = np.linspace(0,10,1000)
y = f(x)
plot(x,y)
