# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import sympy as s

# %%
X = [0, 0, 0, 0, 0]
Y = [1, 1, 3, 5, 5]
U = [4, -4, 0, -4, 4]
V = [3, 3, -9, -5, -5]

# %%
plt.quiver(X, Y, U, V, color=['b', 'b', 'g', 'r','r' ], angles='xy', scale_units='xy', scale=1)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10, 10)
