# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import sympy as s

origin = [0], [0]
U = [3, -3, 0 ,  1]
V = [2, -1, 1 , -2]
plt.quiver(*origin, U, V, color=['g', 'b', 'r', 'y'], angles='xy', scale_units='xy', scale=1)
plt.xlim(-5, 5 )
plt.ylim(-5, 5 )
# Out:
# (-5, 5)
