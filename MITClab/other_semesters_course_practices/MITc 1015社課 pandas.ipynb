# %% [markdown]
# # 請大家先安裝 pandas-datareader
#
# 如果從未安裝過，打開anaconda prompt，輸入 <br/>
#    conda install pandas-datareader <br/>
# 如果安裝過，請輸入 <br/>
#    conda updata pandas-datareader

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# %ls 
#確認目錄下的檔案
# Out:
#  磁碟區 C 中的磁碟沒有標籤。
#  磁碟區序號:  FABB-C27E
#
#  C:\Users\JuliMing\Desktop\python 的目錄
#
# 2019/10/14  下午 07:59    <DIR>          .
# 2019/10/14  下午 07:59    <DIR>          ..
# 2019/10/14  下午 05:46    <DIR>          .ipynb_checkpoints
# 2018/08/28  下午 10:35               890 5 work.py
# 2019/10/14  下午 02:19             2,406 grades.csv
# 2019/10/14  下午 07:20            18,317 HW1解答.png
# 2018/08/26  下午 06:02               567 LPT演算法.py
# 2019/10/14  下午 07:59           495,089 MITc 1015社課 pandas.ipynb
# 2018/08/26  下午 06:56               702 optimize (Q,R)Policy.py
# 2019/10/14  下午 07:08            24,713 sigmoid解答.png
# 2018/08/26  下午 06:14               319 test.py
# 2018/08/28  下午 04:35               604 TSP.py
# 2019/10/14  下午 07:22            22,628 u.user.txt
# 2019/10/14  下午 03:46           668,882 ufo.csv
# 2018/08/28  下午 05:39               717 week 5 execrise.py
# 2019/10/14  下午 06:36            13,412 加權解答.png
# 2019/10/14  下午 06:20             4,872 級分分布表.png
# 2019/10/14  下午 07:55           132,403 問題解答.ipynb
# 2018/08/24  下午 01:46               595 第四周作業 報童問題 .py
# 2019/10/14  下午 06:17            36,141 解答.png
# 2018/08/26  下午 06:16               319 演算法(Q,R)Policy.py
#               18 個檔案       1,423,576 位元組
#                3 個目錄  25,708,421,120 位元組可用

# %%
df = pd.read_csv("grades.csv") #read the file

# %%
df = pd.read_csv("https://raw.githubusercontent.com/yenlung/Python-3-Data-Analysis-Basics/master/grades.csv")

# %%
df.head() #check the file
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
df.head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# 5   張雅岳  13  12  12  12   8
# 6   梁俊翔  11  13  10  10  14
# 7   林金鳳   8   9  10  10   8
# 8   許協旺   9   9  12  10  10
# 9   郭雅惠  10  15  12  11   9
# 10  張志偉  14   9   8  10  12
# 11  周皇樺  13   9  13  14  15
# 12  李正偉  11  15  11  14  15
# 13  黃旭忠  15  14   9  12  10
# 14  葉雅琳   8  13  10  13  14
# 15  黃淑慧  11   8  10  12  15
# 16  吳芝菁  14   9  11  10   9
# 17  聶珮君  12  11  13  12   9
# 18  梁慧君   9   8   8   8  12
# 19  葉曉玲  14   9  11  15   9

# %%
df["國文"] # df.國文 also works
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# 15    11
# 16    14
# 17    12
# 18     9
# 19    14
# 20    13
# 21     9
# 22    12
# 23    10
# 24    10
# 25    13
# 26    13
# 27     8
# 28    15
# 29    14
#       ..
# 70     9
# 71     9
# 72    10
# 73    13
# 74    14
# 75    13
# 76     9
# 77    13
# 78    12
# 79     9
# 80    13
# 81    11
# 82    11
# 83    10
# 84    10
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
cg = df.國文.values

# %%
cg
# Out:
# array([ 9, 10, 13, 10, 13, 13, 11,  8,  9, 10, 14, 13, 11, 15,  8, 11, 14,
#        12,  9, 14, 13,  9, 12, 10, 10, 13, 13,  8, 15, 14,  8, 15,  9, 14,
#        13, 14, 12, 11,  8,  9, 12, 14, 14, 12, 13,  9, 14,  8, 15, 10, 12,
#        14, 12, 14, 15,  9, 11, 12, 10, 11, 14, 14,  8, 12,  9, 13, 10, 14,
#         8, 12,  9,  9, 10, 13, 14, 13,  9, 13, 12,  9, 13, 11, 11, 10, 10,
#        10, 11, 10, 11, 13,  8, 14,  8, 11, 10,  9,  8, 14, 15,  9],
#       dtype=int64)

# %%
cg.mean()
# Out:
# 11.39

# %%
df.國文.mean()
# Out:
# 11.39

# %%
cg.std()
# Out:
# 2.1858407993264284

# %%
df.國文.mean()
# Out:
# 11.39

# %%
df.國文.min()
# Out:
# 8

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %%
df["總級分"] = df[["國文", "英文", "數學", "社會", "自然"]].sum(1)

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %%
df["主科"] =  df.數學*1.5 + df.英文

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分    主科
# 0  劉俊安   9  10  15  10  13   57  32.5
# 1  胡玉華  10  10  10   8   9   47  25.0
# 2  黃淑婷  13  15   8  11  14   61  27.0
# 3  陳上紫  10  10   8   9  14   51  22.0
# 4  崔靜成  13  12  14  12  13   64  33.0

# %%
df.sort_values(by = "總級分", ascending = False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 12  李正偉  11  15  11  14  15   66  31.5
# 54  陳怡潔  15  15   9  15  11   65  28.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 48  陳怡婷  15  14  12   9  15   65  32.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 87  趙偉希  10  13  14  13  15   65  34.0
# 4   崔靜成  13  12  14  12  13   64  33.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 11  周皇樺  13   9  13  14  15   64  28.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 67  林哲法  14   9  15  10  14   62  31.5
# 20  陳智超  13   9  13  14  13   62  28.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 44  童心怡  13  13  14   8  13   61  34.0

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分    主科
# 0  劉俊安   9  10  15  10  13   57  32.5
# 1  胡玉華  10  10  10   8   9   47  25.0
# 2  黃淑婷  13  15   8  11  14   61  27.0
# 3  陳上紫  10  10   8   9  14   51  22.0
# 4  崔靜成  13  12  14  12  13   64  33.0

# %%
df.sort_values(by = "總級分", ascending = False, inplace = True)

# %%
df.sort_values(by = ["主科", "總級分"],ascending = False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 73  吳志遠  13  15  15   8   8   59  37.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 70  葉儀依   9  13  15   8  14   59  35.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 66  邱盈俊  10  14  14  13   8   59  35.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 87  趙偉希  10  13  14  13  15   65  34.0
# 44  童心怡  13  13  14   8  13   61  34.0
# 27  馮白屏   8  13  14   8  10   53  34.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 90  胡勝傑   8  11  15  10  15   59  33.5
# 85  張雅彬  10  11  15  12   8   56  33.5
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 4   崔靜成  13  12  14  12  13   64  33.0

# %%
df.國文.plot()

# %%
df.國文.hist(bins = 16)

# %%
df.國文.plot(kind = "hist",bins = 16)

# %% [markdown]
# # Problem1
# 小明是某所高中的社會組老師，為了看看大家能夠上哪個學校的財金系，小明想知道所有人的加權級分是多少，你能幫幫他嗎？<br/>
# 權重為 [1, 1.5, 2, 0,1] <br/>
# 請幫他在上面的表格最後面加上一個"加權級分"的欄位，並且顯示所有學生的加權級分，並由大到小排序，並在最後顯示前20個做確認。<br/>
# 最後在用hist畫出一個級分分布圖

# %% [markdown]
# 做出來會像這樣 <br/>
#
# ![%E8%A7%A3%E7%AD%94.png](attachment:%E8%A7%A3%E7%AD%94.png)
# ![%E7%B4%9A%E5%88%86%E5%88%86%E5%B8%83%E8%A1%A8.png](attachment:%E7%B4%9A%E5%88%86%E5%88%86%E5%B8%83%E8%A1%A8.png)

# %% [markdown]
# Hint : 表格上的數字可以直接和加權相乘並相加，但要怎麼做呢？

# %% [markdown]
# # 製作DataFrame

# %%
mydata = np.random.randn(4,3) # what is the different from np.random.rand?

# %%
plt.hist(np.random.rand(100000))
# Out:
# (array([10137.,  9845., 10085.,  9988., 10045.,  9931.,  9935., 10007.,
#         10069.,  9958.]),
#  array([9.84029932e-06, 1.00008435e-01, 2.00007029e-01, 3.00005623e-01,
#         4.00004218e-01, 5.00002812e-01, 6.00001406e-01, 7.00000001e-01,
#         7.99998595e-01, 8.99997189e-01, 9.99995783e-01]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.random.randn(100000))
# Out:
# (array([2.7000e+01, 4.3400e+02, 3.7890e+03, 1.5341e+04, 3.1006e+04,
#         3.0646e+04, 1.4729e+04, 3.5760e+03, 4.3000e+02, 2.2000e+01]),
#  array([-4.34738185, -3.47529673, -2.60321161, -1.73112649, -0.85904137,
#          0.01304375,  0.88512887,  1.75721399,  2.62929911,  3.50138424,
#          4.37346936]),
#  <a list of 10 Patch objects>)

# %%
mydata
# Out:
# array([[ 0.02113464, -1.53602116, -0.63991246],
#        [-0.89224529,  0.06463006, -0.62046829],
#        [-0.4729008 , -1.21823907,  1.14585595],
#        [-0.74899495,  0.61323244,  2.13725087]])

# %%
df1 = pd.DataFrame(mydata,columns = list("ABC")

# %%
df1
# Out:
#           A         B         C
# 0  0.664251  0.255965  0.934166
# 1 -0.257753 -2.514375  0.484863
# 2 -0.400292  0.690551  0.120400
# 3  0.479990 -0.688018 -0.731500

# %%
mydata2 = np.random.rand(3,3)
df2 = pd.DataFrame(mydata2, columns = list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  0.577274  0.990497  0.942852
# 1  0.299274  0.274629  0.862451
# 2  0.862848  0.703917  0.669048

# %%
df3 = pd.concat([df1, df2], axis = 0)

# %%
df3
# Out:
#           A         B         C
# 0  0.664251  0.255965  0.934166
# 1 -0.257753 -2.514375  0.484863
# 2 -0.400292  0.690551  0.120400
# 3  0.479990 -0.688018 -0.731500
# 0  0.577274  0.990497  0.942852
# 1  0.299274  0.274629  0.862451
# 2  0.862848  0.703917  0.669048

# %%
df3.index = range(7)

# %%
df3
# Out:
#           A         B         C
# 0  0.664251  0.255965  0.934166
# 1 -0.257753 -2.514375  0.484863
# 2 -0.400292  0.690551  0.120400
# 3  0.479990 -0.688018 -0.731500
# 4  0.577274  0.990497  0.942852
# 5  0.299274  0.274629  0.862451
# 6  0.862848  0.703917  0.669048

# %%
df4 = pd.DataFrame(df3,columns = list("ABC"),index = range(7))

# %%
df4
# Out:
#           A         B         C
# 0  0.664251  0.255965  0.934166
# 1 -0.257753 -2.514375  0.484863
# 2 -0.400292  0.690551  0.120400
# 3  0.479990 -0.688018 -0.731500
# 4  0.577274  0.990497  0.942852
# 5  0.299274  0.274629  0.862451
# 6  0.862848  0.703917  0.669048

# %% [markdown]
# # Problem 2

# %% [markdown]
# 因為不是所有學生都想要念財金，因此小明受學生之託收集了其他科系的加權，能不能幫小明做出來加權表格呢？<br/>
# 科目分別是 <br/>
# ["國文","英文","數學","自然","社會"] <br/>
# 各科的加權分別為：<br/>
# {<br/>
# "土語系": [2,2,1,0,1],<br/>
# "財政系": [1, 1.5, 1.5,0,0],<br/>
# "金融系": [1, 1.5, 2,0,1],<br/>
# "國貿系": [1.5, 2, 2,0,0],<br/>
# "會計系": [1.5, 2, 2,0,1],<br/>
# "法律系": [1, 2, 1,0,2],<br/>
# "公行系": [1, 1.5,1.25,0,1.25],<br/>
# "應數系": [1, 1, 1.5,1.5,0],<br/>
# "教育系": [1.5, 2, 1.25,0,1.5]<br/>
# }<br/>

# %% [markdown]
# 做出來會像這樣
# ![%E5%8A%A0%E6%AC%8A%E8%A7%A3%E7%AD%94.png](attachment:%E5%8A%A0%E6%AC%8A%E8%A7%A3%E7%AD%94.png)

# %% [markdown]
# Hint : <br/>
#     1.命名row的名字用index，命名column的名字用columns。<br/>
#        2.可以直接複製所給的資料，科目的type為list，各科的加權為dict。 <br/>

# %% [markdown]
# # loc 定位法

# %%
df = pd.DataFrame(np.random.randn(5,3),index = list(range(1,6)),columns = list("ABC"))

# %%
df
# Out:
#           A         B         C
# 1 -1.157546  0.941795 -1.423141
# 2 -0.571636  1.446219  0.868191
# 3  0.672136 -0.196310  0.749832
# 4 -0.488930 -0.498241  0.766979
# 5 -0.668746  2.052430  0.192745

# %%
df[df.B>0]
# Out:
#           A         B         C
# 1 -1.157546  0.941795 -1.423141
# 2 -0.571636  1.446219  0.868191
# 5 -0.668746  2.052430  0.192745

# %%
df[df.B>0]["C"] = 0 #it doest work, then how?
# Out:
# D:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           A         B         C
# 1 -1.157546  0.941795 -1.423141
# 2 -0.571636  1.446219  0.868191
# 3  0.672136 -0.196310  0.749832
# 4 -0.488930 -0.498241  0.766979
# 5 -0.668746  2.052430  0.192745

# %%
df.loc[2,"B"]
# Out:
# 1.4462186902821474

# %%
df.loc[2,"B"] = 1

# %%
df
# Out:
#           A         B         C
# 1 -1.157546  0.941795 -1.423141
# 2 -0.571636  1.000000  0.868191
# 3  0.672136 -0.196310  0.749832
# 4 -0.488930 -0.498241  0.766979
# 5 -0.668746  2.052430  0.192745

# %%
df.loc[2:3, "B":"C"]
# Out:
#          B         C
# 2  1.00000  0.868191
# 3 -0.19631  0.749832

# %%
df[df.B>0]
# Out:
#           A         B         C
# 1 -1.157546  0.941795 -1.423141
# 2 -0.571636  1.000000  0.868191
# 5 -0.668746  2.052430  0.192745

# %%
df.loc[df.B>0,["C"]] =0

# %%
df
# Out:
#           A         B         C
# 1 -1.157546  0.941795  0.000000
# 2 -0.571636  1.000000  0.000000
# 3  0.672136 -0.196310  0.749832
# 4 -0.488930 -0.498241  0.766979
# 5 -0.668746  2.052430  0.000000

# %% [markdown]
# # Problem3

# %% [markdown]
# 利用np.random.randn函數，做出一個20X3的DataFrame，Row的名稱為1:20，Col的名稱為A、B、C。 <br/>
# 並且這個DataFrame所有小於0的數字都改成0。

# %% [markdown]
# 結果會像這樣![sigmoid%E8%A7%A3%E7%AD%94.png](attachment:sigmoid%E8%A7%A3%E7%AD%94.png)

# %% [markdown]
# # 試試看分析資料吧

# %% [markdown]
# # UFO

# %%
df = pd.read_csv("http://bit.ly/uforeports")

# %%
df = pd.read_csv("ufo.csv")

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_state = df.groupby("State").count()

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# KS      176               33             144   176
# KY      244               34             220   244
# LA      172               16             148   174
# MA      322               50             276   322
# MD      215               34             185   215
# ME      181               28             153   181
# MI      590               78             504   591
# MN      254               40             223   254
# MO      448               86             386   448
# MS      139               17             126   139
# MT      143               22             114   144
# NC      356               55             325   356
# ND       51                5              43    51
# NE      101                7              89   101
# NH      124               20             113   125
# NJ      370               51             326   370
# NM      241               28             193   241
# NV      281               45             236   284
# NY      913              123             823   914
# OH      665               93             605   667
# OK      193               22             167   193
# OR      534               89             414   534
# PA      598               97             519   598
# RI       67                8              62    67
# SC      166               22             148   166
# SD       57               10              39    57
# TN      286               41             247   286
# TX     1025              138             923  1027
# UT      193               36             172   193
# VA      299               51             253   299
# VT       44                6              34    44
# WA     1320              269             925  1322
# WI      357               63             312   357
# WV      131               13             112   132
# WY       69                6              57    69

# %%
df_state.describe() #not useful
# Out:
#               City  Colors Reported  Shape Reported         Time
# count    52.000000        52.000000       52.000000    52.000000
# mean    350.307692        55.423077      299.942308   350.788462
# std     412.526008        74.588898      347.159534   413.201624
# min       1.000000         0.000000        0.000000     1.000000
# 25%     130.750000        16.750000      112.750000   131.500000
# 50%     220.000000        33.500000      187.000000   220.000000
# 75%     367.750000        60.750000      325.250000   367.750000
# max    2525.000000       457.000000     2148.000000  2529.000000

# %%
df_state.sort_values(by = "Time" , ascending = False , inplace = True)

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# GA      325               44             294   325
# MA      322               50             276   322
# VA      299               51             253   299
# TN      286               41             247   286
# NV      281               45             236   284
# MN      254               40             223   254
# KY      244               34             220   244
# NM      241               28             193   241
# CT      225               25             188   225
# MD      215               34             185   215
# AR      206               26             186   206
# OK      193               22             167   193
# AL      193               21             173   193
# UT      193               36             172   193
# ME      181               28             153   181
# KS      176               33             144   176
# LA      172               16             148   174
# SC      166               22             148   166
# IA      162               28             142   162
# MT      143               22             114   144
# MS      139               17             126   139
# WV      131               13             112   132
# ID      130               12             109   130
# NH      124               20             113   125
# AK      116               25              99   116
# NE      101                7              89   101
# HI       85               16              74    85
# WY       69                6              57    69
# RI       67                8              62    67
# SD       57               10              39    57
# ND       51                5              43    51
# VT       44                6              34    44
# DE       43                5              38    43
# Fl        4                1               0     4
# Ca        1                0               1     1

# %%
df_state.head(10).Time.plot(kind = "bar")

# %% [markdown]
# # 股票分析

# %%
import pandas_datareader as web

# %%
df = web.DataReader("AAPL", "yahoo", start = "2012-9-1", end = "2019-10-14") #web.DataReader(公司名稱,來源,起始天數,結束天數)

# %%
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-08-31  95.514282  93.892860  95.321426  95.034286  84580300.0  83.293762
# 2012-09-04  96.448570  94.928574  95.108574  96.424286  91973000.0  84.512062
# 2012-09-05  96.621429  95.657143  96.510002  95.747147  84093800.0  83.918564
# 2012-09-06  96.898575  95.828575  96.167145  96.610001  97799100.0  84.674820
# 2012-09-07  97.497147  96.538574  96.864288  97.205711  82416600.0  85.196938

# %% [markdown]
# # Take "Adj Close" for example

# %%
P = df["Adj Close"]

# %%
P.head()
# Out:
# Date
# 2012-08-31    83.293762
# 2012-09-04    84.512062
# 2012-09-05    83.918564
# 2012-09-06    84.674820
# 2012-09-07    85.196938
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %% [markdown]
# # 計算報酬率

# %% [markdown]
#  # Earning*100 / Price

# %%
P.diff() #這一期的價格-前一期的價格 = Earning
# Out:
# Date
# 2012-08-31         NaN
# 2012-09-04    1.218300
# 2012-09-05   -0.593498
# 2012-09-06    0.756256
# 2012-09-07    0.522118
# 2012-09-10   -2.216194
# 2012-09-11   -0.269203
# 2012-09-12    1.151932
# 2012-09-13    1.651505
# 2012-09-14    1.039238
# 2012-09-17    1.064270
# 2012-09-18    0.266685
# 2012-09-19    0.023788
# 2012-09-20   -0.425713
# 2012-09-21    0.174057
# 2012-09-24   -1.164444
# 2012-09-25   -2.159859
# 2012-09-26   -1.046745
# 2012-09-27    2.020859
# 2012-09-28   -1.780441
# 2012-10-01   -0.965378
# 2012-10-02    0.240410
# 2012-10-03    1.269630
# 2012-10-04   -0.582253
# 2012-10-05   -1.779198
# 2012-10-08   -1.805534
# 2012-10-09   -0.290474
# 2012-10-10    0.633583
# 2012-10-11   -1.603943
# 2012-10-12    0.201584
#                 ...
# 2019-08-30   -0.269989
# 2019-09-03   -3.040009
# 2019-09-04    3.490005
# 2019-09-05    4.089996
# 2019-09-06   -0.020004
# 2019-09-09    0.910004
# 2019-09-10    2.529999
# 2019-09-11    6.889999
# 2019-09-12   -0.500000
# 2019-09-13   -4.339996
# 2019-09-16    1.149994
# 2019-09-17    0.800003
# 2019-09-18    2.070007
# 2019-09-19   -1.809998
# 2019-09-20   -3.230011
# 2019-09-23    0.990005
# 2019-09-24   -1.040009
# 2019-09-25    3.350006
# 2019-09-26   -1.139999
# 2019-09-27   -1.069992
# 2019-09-30    5.149994
# 2019-10-01    0.619995
# 2019-10-02   -5.629990
# 2019-10-03    1.860001
# 2019-10-04    6.189987
# 2019-10-07    0.050003
# 2019-10-08   -2.660004
# 2019-10-09    2.630005
# 2019-10-10    3.059998
# 2019-10-11    6.120010
# Name: Adj Close, Length: 1789, dtype: float64

# %%
r = P.diff()*100/P

# %%
r.plot()

# %%
r[-100:].plot()

# %% [markdown]
# # 簡單移動平均 SMA

# %%
P.rolling(window = 20).mean()
# Out:
# Date
# 2012-08-31           NaN
# 2012-09-04           NaN
# 2012-09-05           NaN
# 2012-09-06           NaN
# 2012-09-07           NaN
# 2012-09-10           NaN
# 2012-09-11           NaN
# 2012-09-12           NaN
# 2012-09-13           NaN
# 2012-09-14           NaN
# 2012-09-17           NaN
# 2012-09-18           NaN
# 2012-09-19           NaN
# 2012-09-20           NaN
# 2012-09-21           NaN
# 2012-09-24           NaN
# 2012-09-25           NaN
# 2012-09-26           NaN
# 2012-09-27           NaN
# 2012-09-28     85.236008
# 2012-10-01     85.199384
# 2012-10-02     85.113866
# 2012-10-03     85.121505
# 2012-10-04     85.062218
# 2012-10-05     84.887865
# 2012-10-08     84.734046
# 2012-10-09     84.579163
# 2012-10-10     84.398362
# 2012-10-11     84.054789
# 2012-10-12     83.669333
#                  ...
# 2019-08-30    204.680957
# 2019-09-03    205.335548
# 2019-09-04    205.982331
# 2019-09-05    206.732001
# 2019-09-06    207.262001
# 2019-09-09    207.921001
# 2019-09-10    208.732001
# 2019-09-11    209.463000
# 2019-09-12    210.480000
# 2019-09-13    211.330500
# 2019-09-16    212.000500
# 2019-09-17    212.517999
# 2019-09-18    213.138499
# 2019-09-19    213.554500
# 2019-09-20    213.817999
# 2019-09-23    214.621999
# 2019-09-24    215.181499
# 2019-09-25    216.024998
# 2019-09-26    216.742999
# 2019-09-27    217.233499
# 2019-09-30    217.994999
# 2019-10-01    218.939499
# 2019-10-02    219.427999
# 2019-10-03    219.805000
# 2019-10-04    220.492500
# 2019-10-07    221.137000
# 2019-10-08    221.521999
# 2019-10-09    221.693999
# 2019-10-10    222.043999
# 2019-10-11    222.917000
# Name: Adj Close, Length: 1789, dtype: float64

# %%
P.rolling(window=20).mean().plot()

# %%
P.plot()

# %%
P.plot()
P.rolling(window=20).mean().plot()

# %% [markdown]
# # HomeWork

# %% [markdown]
# # Problem1

# %% [markdown]
# 小明今年考大學 <br/>
# 依照 [“國文”, “英文”, “數甲”, “數乙”, “物理”, “化學”, “生物”, “歷史”, “地理”, “公民”] <br/>
# 他的分數分別是 [86.5, 79.4, 88.2, 96.5, 86.3, 76.8, 96.1, 78.5, 82.4, 88.6] <br/>
# 而他所想申請的大學各系採計的科目權重分別是 <br/>
# {<br/>
# "土語系": [2, 2, 0, 1, 0, 0, 0, 1, 1, 0], <br/>
# "財政系": [1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0], <br/>
# "金融系": [1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0], <br/>
# "國貿系": [1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0], <br/>
# "會計系": [1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0], <br/>
# "法律系": [1, 2, 0, 1, 0, 0, 0, 1, 0, 1], <br/>
# "公行系": [1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25], <br/>
# "應數系": [1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0], <br/>
# "教育系": [1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0] <br/>
# }<br/>
#
# 請幫他做出一個表格<br/>
# 第一欄顯示科系<br/>
# 接下來顯示權重 並標示科目<br/>
# 最後一欄顯示加權分數
# 並將加權分數依照高低排序

# %% [markdown]
# Hint : 基本上就是Problem1和Problem2的混合版，只是參數變多了而已。

# %% [markdown]
# 最後結果應該長這樣
# ![HW1%E8%A7%A3%E7%AD%94.png](attachment:HW1%E8%A7%A3%E7%AD%94.png)

# %% [markdown]
# # Problem2

# %% [markdown]
# 這個資料是一個名叫Chipotle的餐廳的訂餐資料，網址為"https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv" 請就這個資料作數據分析。<br/>
# (a)<br/>
# 請以賣出數量由大排到小，並以賣出數量大於100的商品畫一張bar chart。<br/>
# (b)<br/>
# 請以商品價格由大排到小。

# %% [markdown]
# Hint : 因為資料是以tab做分隔(一般而言是用逗號）的關係，直接讀是讀不進去的。<br/>
#                     因此，必須寫成pd.read_csv("網址",delimiter="\t")，讓資料能夠讀進去。(t表示tab)

# %% [markdown]
# # 所有答案都會在禮拜日晚上PO在社團上喔，請大家記得寫作業練習，並且再對答案喔。
