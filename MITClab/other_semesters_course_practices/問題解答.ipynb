# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 64A7-B7E2
#
#  Directory of C:\Users\User\Desktop\MITC 20191015
#
# 10/22/2019  08:43 PM    <DIR>          .
# 10/22/2019  08:43 PM    <DIR>          ..
# 10/15/2019  04:19 PM    <DIR>          .ipynb_checkpoints
# 10/15/2019  04:19 PM           170,394 1008第二堂課 (1).ipynb
# 10/15/2019  06:17 PM             9,046 190915181717.jpg
# 10/15/2019  11:44 PM           424,013 72131374_370740157168022_2172423320497029120_n.jpg
# 10/15/2019  11:44 PM           427,307 72297001_724164194766433_7034245756047327232_n.jpg
# 10/15/2019  11:44 PM           508,268 72321859_385250052364134_4328451273356476416_n.jpg
# 10/14/2019  02:19 PM             2,406 grades.csv
# 10/14/2019  07:20 PM            18,317 HW1解答.png
# 10/22/2019  08:43 PM           498,163 MITc 1015社課 pandas.ipynb
# 10/14/2019  07:08 PM            24,713 sigmoid解答.png
# 10/14/2019  07:22 PM            22,628 u.user.txt
# 10/14/2019  03:46 PM           668,882 ufo.csv
# ...

# %%
df = pd.read_csv("grades.csv")

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
df["主科"] = df.數學*1.5+df.英文

# %% [markdown]
# # Problem1

# %%
weight = [1,1.5,2,0,1]

# %%
df["加權級分"] = (weight * df[["國文","英文","數學","自然","社會"]]).sum(1)

# %%
df.sort_values(by="加權級分",ascending = False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會    主科  加權級分
# 36  詹威德  12  13  15  10  14  35.5  75.5
# 48  陳怡婷  15  14  12   9  15  32.0  75.0
# 83  李士賢  10  14  15  13  13  36.5  74.0
# 44  童心怡  13  13  14   8  13  34.0  73.5
# 73  吳志遠  13  15  15   8   8  37.5  73.5
# 57  胡淳茜  12  15  14  13  11  36.0  73.5
# 37  曾怡君  11  12  15  13  14  34.5  73.0
# 87  趙偉希  10  13  14  13  15  34.0  72.5
# 25  蔡亦瑄  13  13  14  13  12  34.0  72.5
# 80  施雅鈴  13  15  12  13  13  33.0  72.5
# 70  葉儀依   9  13  15   8  14  35.5  72.5
# 4   崔靜成  13  12  14  12  13  33.0  72.0
# 24  陳竹伯  10  12  15  10  14  34.5  72.0
# 67  林哲法  14   9  15  10  14  31.5  71.5
# 64  俞志峰   9  14  13  14  15  33.5  71.0
# 68  劉麗芬   8  14  14  14  14  35.0  71.0
# 12  李正偉  11  15  11  14  15  31.5  70.5
# 90  胡勝傑   8  11  15  10  15  33.5  69.5
# 65  謝雅琳  13  14  13  12   9  33.5  69.0
# 60  曾昇喬  14  12  11   8  15  28.5  69.0

# %%
df.加權級分.plot(kind = "hist")

# %% [markdown]
# # Problem2

# %%
weight = {
"土語系": [2,2,1,0,1],
"財政系": [1, 1.5, 1.5,0,0],
"金融系": [1, 1.5, 2,0,1],
"國貿系": [1.5, 2, 2,0,0],
"會計系": [1.5, 2, 2,0,1],
"法律系": [1, 2, 1,0,2],
"公行系": [1, 1.5,1.25,0,1.25],
"應數系": [1, 1, 1.5,1.5,0],
"教育系": [1.5, 2, 1.25,0,1.5]
}

# %%
subject = ["國文","英文","數學","自然","社會"]

# %%
weight.values()
# Out:
# dict_values([[2, 2, 1, 0, 1], [1, 1.5, 1.5, 0, 0], [1, 1.5, 2, 0, 1], [1.5, 2, 2, 0, 0], [1.5, 2, 2, 0, 1], [1, 2, 1, 0, 2], [1, 1.5, 1.25, 0, 1.25], [1, 1, 1.5, 1.5, 0], [1.5, 2, 1.25, 0, 1.5]])

# %%
df = pd.DataFrame(list(weight.values()),columns = subject,index = weight.keys())

# %%
df
# Out:
#       國文   英文    數學   自然    社會
# 土語系  2.0  2.0  1.00  0.0  1.00
# 財政系  1.0  1.5  1.50  0.0  0.00
# 金融系  1.0  1.5  2.00  0.0  1.00
# 國貿系  1.5  2.0  2.00  0.0  0.00
# 會計系  1.5  2.0  2.00  0.0  1.00
# 法律系  1.0  2.0  1.00  0.0  2.00
# 公行系  1.0  1.5  1.25  0.0  1.25
# 應數系  1.0  1.0  1.50  1.5  0.00
# 教育系  1.5  2.0  1.25  0.0  1.50

# %% [markdown]
# # Problem3

# %%
df = pd.DataFrame(np.random.randn(20,3),columns = list("ABC"),index = list(range(1,21)))

# %%
df
# Out:
#            A         B         C
# 1  -0.309754  3.220651 -1.253364
# 2   0.643294 -1.151034 -0.228302
# 3   0.821192 -0.696029 -0.148797
# 4   1.984674  0.163448  0.575436
# 5  -0.782314 -0.548876 -0.435916
# 6  -0.965614 -1.088097  0.219078
# 7   1.306223  0.556775  0.460644
# 8   0.796271  1.343751  0.288475
# 9  -0.784347 -0.268009  2.353492
# 10  1.485073  0.359942 -0.688832
# 11 -0.549244 -0.658439 -0.282692
# 12  0.017709  0.083499  0.204778
# 13 -0.016395  0.325015  0.297247
# 14  1.208920 -0.723303 -0.901130
# 15 -1.830661 -1.837708  1.829849
# 16 -1.726260 -0.983600 -0.724907
# 17 -0.490976 -0.152236  0.740861
# 18 -0.336535  0.368055 -1.819564
# 19 -0.052973 -0.241611 -0.174037
# 20 -0.811490 -1.210332 -0.265447

# %%
df.loc[df.A<0,["A"]]=0
df.loc[df.B<0,["B"]]=0
df.loc[df.C<0,["C"]]=0

# %%
df
# Out:
#            A         B         C
# 1   0.000000  3.220651  0.000000
# 2   0.643294  0.000000  0.000000
# 3   0.821192  0.000000  0.000000
# 4   1.984674  0.163448  0.575436
# 5   0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.219078
# 7   1.306223  0.556775  0.460644
# 8   0.796271  1.343751  0.288475
# 9   0.000000  0.000000  2.353492
# 10  1.485073  0.359942  0.000000
# 11  0.000000  0.000000  0.000000
# 12  0.017709  0.083499  0.204778
# 13  0.000000  0.325015  0.297247
# 14  1.208920  0.000000  0.000000
# 15  0.000000  0.000000  1.829849
# 16  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.740861
# 18  0.000000  0.368055  0.000000
# 19  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000

# %% [markdown]
# # HomeWork

# %% [markdown]
# # Problem1

# %%
subject = ["國文", "英文", "數甲", "數乙", "物理", "化學", "生物", "歷史", "地理", "公民"]

# %%
grade = [86.5,79.4,88.2,96.5,86.3,76.8,96.1,78.5,82.4,88.6]

# %%
weight = {
"土語系": [2, 2, 0, 1, 0, 0, 0, 1, 1, 0],
"財政系": [1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0],
"金融系": [1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0],
"國貿系": [1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0],
"會計系": [1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0],
"法律系": [1, 2, 0, 1, 0, 0, 0, 1, 0, 1],
"公行系": [1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25],
"應數系": [1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0],
"教育系": [1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0]
}

# %%
weight.keys()
# Out:
# dict_keys(['土語系', '財政系', '金融系', '國貿系', '會計系', '法律系', '公行系', '應數系', '教育系'])

# %%
df = pd.DataFrame(list(weight.values()),columns = subject,index = weight.keys())

# %%
df
# Out:
#       國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民
# 土語系  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00
# 財政系  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00
# 金融系  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00
# 國貿系  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00
# 會計系  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00
# 法律系  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00
# 公行系  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25
# 應數系  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00
# 教育系  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00

# %%
df["加權分數"]= grade*weight.values() #it doesnt work, then how?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8f3fde2eaeee> in <module>()
# ----> 1 df["加權分數"]= grade*weight.values() #it doesnt work, then how?
#
# TypeError: can't multiply sequence by non-int of type 'dict_values'

# %%
df["加權分數"] = (grade*df[["國文", "英文", "數甲", "數乙", "物理", "化學", "生物", "歷史", "地理", "公民"]]).sum(1)

# %%
df
# Out:
#       國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民     加權分數
# 土語系  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00  589.200
# 財政系  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00  350.350
# 金融系  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00  398.600
# 國貿系  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00  481.550
# 會計系  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00  642.450
# 法律系  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00  508.900
# 公行系  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25  436.975
# 應數系  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00  461.300
# 教育系  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00  570.075

# %%
df.sort_values(by = "加權分數", ascending = False )
# Out:
#       國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民     加權分數
# 會計系  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00  642.450
# 土語系  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00  589.200
# 教育系  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00  570.075
# 法律系  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00  508.900
# 國貿系  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00  481.550
# 應數系  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00  461.300
# 公行系  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25  436.975
# 金融系  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00  398.600
# 財政系  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00  350.350

# %% [markdown]
# # Problem2

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv",delimiter="\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # (a)

# %%
df_item = df.groupby("item_name").count()

# %%
df_item.sort_values(by="quantity",ascending = False)
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# Chicken Bowl                                726       726                 726
# Chicken Burrito                             553       553                 553
# Chips and Guacamole                         479       479                   0
# Steak Burrito                               368       368                 368
# Canned Soft Drink                           301       301                 301
# Steak Bowl                                  211       211                 211
# Chips                                       211       211                   0
# Bottled Water                               162       162                   0
# Chicken Soft Tacos                          115       115                 115
# Chicken Salad Bowl                          110       110                 110
# Chips and Fresh Tomato Salsa                110       110                   0
# ...

# %%
df_item = df_item[df_item.quantity > 100]
df_item.quantity.plot(kind = "bar")

# %% [markdown]
# # (b)

# %%
df.sort_values(by="item_price",ascending = False)
# Out:
#       order_id  quantity              item_name  \
# 2624      1042         1       Steak Salad Bowl
# 4419      1762         1       Steak Salad Bowl
# 4036      1615         1       Steak Salad Bowl
# 1825       738         1    Barbacoa Salad Bowl
# 3115      1243         1    Carnitas Salad Bowl
# 4547      1807         1       Steak Salad Bowl
# 3098      1235         1       Steak Salad Bowl
# 4241      1693         1       Steak Salad Bowl
# 1418       576         1    Barbacoa Salad Bowl
# 4391      1752         1       Steak Salad Bowl
# 4572      1818         1       Steak Salad Bowl
# 2600      1032         1       Steak Salad Bowl
# 607        250         1       Steak Salad Bowl
# 4390      1751         1    Barbacoa Salad Bowl
# 1865       756         1    Carnitas Salad Bowl
# 1421       576         1    Barbacoa Salad Bowl
# 3356      1346         1    Barbacoa Salad Bowl
# 1789       724         1    Carnitas Soft Tacos
# ...
